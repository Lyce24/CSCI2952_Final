# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("anasmohammedtahir/covidqu")

print("Path to dataset files:", path)

# %%
import os

data_dict = {}

os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data")

for dir_path in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data"):
    if dir_path == "Train":
        for sub_dir in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data/Train"):
            print(sub_dir)
            for sub_sub_dir in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data/Train/" + sub_dir):
                if sub_sub_dir == "images":
                    for file_name in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data/Train/" + sub_dir + "/" + sub_sub_dir):
                        data_dict[file_name] = (sub_dir, "Train")
    elif dir_path == "Test":
        for sub_dir in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data/Test"):
            print(sub_dir)
            for sub_sub_dir in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data/Test/" + sub_dir):
                if sub_sub_dir == "images":
                    for file_name in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data/Test/" + sub_dir + "/" + sub_sub_dir):
                        data_dict[file_name] = (sub_dir, "Test")
    elif dir_path == "Val":
        for sub_dir in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data/Val"):
            print(sub_dir)
            for sub_sub_dir in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data/Val/" + sub_dir):
                if sub_sub_dir == "images":
                    for file_name in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data/Val/" + sub_dir + "/" + sub_sub_dir):
                        data_dict[file_name] = (sub_dir, "Val")

# %%
# import os
# import shutil

# os.makedirs("../../../.cache/kagglehub/datasets/anasmohammedtahir/covidqu/versions/7/images", exist_ok=True)
# new_image_path = "../../../.cache/kagglehub/datasets/anasmohammedtahir/covidqu/versions/7/images"


# for dir_path in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data"):
#     if dir_path == "Train":
#         for sub_dir in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data/Train"):
#             print(sub_dir)
#             for sub_sub_dir in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data/Train/" + sub_dir):
#                 if sub_sub_dir == "images":
#                     for file_name in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data/Train/" + sub_dir + "/" + sub_sub_dir):
#                         # copy the image to the new images directory, don't rename or move. just copy
#                         shutil.copy(path + "/Lung Segmentation Data/Lung Segmentation Data/Train/" + sub_dir + "/" + sub_sub_dir + "/" + file_name,
#                                     os.path.join(new_image_path, file_name))

#     elif dir_path == "Test":
#         for sub_dir in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data/Test"):
#             print(sub_dir)
#             for sub_sub_dir in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data/Test/" + sub_dir):
#                 if sub_sub_dir == "images":
#                     for file_name in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data/Test/" + sub_dir + "/" + sub_sub_dir):
#                         # copy the image to the new images directory
#                         shutil.copy(path + "/Lung Segmentation Data/Lung Segmentation Data/Test/" + sub_dir + "/" + sub_sub_dir + "/" + file_name,
#                                     os.path.join(new_image_path, file_name))
#     elif dir_path == "Val":
#         for sub_dir in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data/Val"):
#             print(sub_dir)
#             for sub_sub_dir in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data/Val/" + sub_dir):
#                 if sub_sub_dir == "images":
#                     for file_name in os.listdir(path + "/Lung Segmentation Data/Lung Segmentation Data/Val/" + sub_dir + "/" + sub_sub_dir):
#                         # copy the image to the new images directory
#                         shutil.copy(path + "/Lung Segmentation Data/Lung Segmentation Data/Val/" + sub_dir + "/" + sub_sub_dir + "/" + file_name,
#                                     os.path.join(new_image_path, file_name))

# %%
len(os.listdir("../../../.cache/kagglehub/datasets/anasmohammedtahir/covidqu/versions/7/images"))

# %%
import pandas as pd

# create a dataframe from data_dict
data_list = []
for file_name, (label, split) in data_dict.items():
    data_list.append({"Path": file_name, "Label": label, "Split": split})

df = pd.DataFrame(data_list)
df.head()

# %%
# in the dataframe, replace label "COVID-19" with 1, Non-COVID with 2, Normal with 0
df["Label"] = df["Label"].replace({"COVID-19": 1, "Non-COVID": 2, "Normal": 0})
df.head()

# %%
# create train, val, test splits
train_df = df[df["Split"] == "Train"].reset_index(drop=True)
val_df = df[df["Split"] == "Val"].reset_index(drop=True)
test_df = df[df["Split"] == "Test"].reset_index(drop=True)

print("Train size:", len(train_df))
print("Val size:", len(val_df))
print("Test size:", len(test_df))

train_df.to_csv("../src/covidqu_train_split.csv", index=False)
val_df.to_csv("../src/covidqu_val_split.csv", index=False)
test_df.to_csv("../src/covidqu_test_split.csv", index=False)

# %%
# for each dataframe, print the distribution of labels
print("Train label distribution:")
print(train_df["Label"].value_counts())
print("Val label distribution:")
print(val_df["Label"].value_counts())
print("Test label distribution:")
print(test_df["Label"].value_counts())
